# %%
import numpy as np
import pandas as pd

# %%
#random seed
np.random.seed(42)

set1no=900
set2no=100

# %%
df1 = pd.DataFrame({
        "feature_1":np.random.normal(loc=0 ,scale=1, size=set1no),
        "feature_2":np.random.normal(loc=0 ,scale=1, size=set1no),
        "target": [0] * set1no
})

df2 = pd.DataFrame({
        "feature_1":np.random.normal(loc=0 ,scale=1, size=set2no),
        "feature_2":np.random.normal(loc=0 ,scale=1, size=set2no),
        "target": [1] * set2no
})

# %%
df1.head()
# Out:
#    feature_1  feature_2  target
# 0   0.496714   0.368673       0
# 1  -0.138264  -0.393339       0
# 2   0.647689   0.028745       0
# 3   1.523030   1.278452       0
# 4  -0.234153   0.191099       0

# %%
df2.head()
# Out:
#    feature_1  feature_2  target
# 0   1.901191   0.696954       1
# 1  -0.060661  -0.333819       1
# 2  -0.708407   1.173125       1
# 3  -1.513714   0.369642       1
# 4  -1.803140  -0.107302       1

# %%
df=pd.concat([df1,df2]).reset_index(drop=True)

# %%
df
# Out:
#      feature_1  feature_2  target
# 0     0.496714   0.368673       0
# 1    -0.138264  -0.393339       0
# 2     0.647689   0.028745       0
# 3     1.523030   1.278452       0
# 4    -0.234153   0.191099       0
# ..         ...        ...     ...
# 995  -0.370011   1.070150       1
# 996  -0.258796  -0.026521       1
# 997   1.598647  -0.881875       1
# 998   0.560919  -0.163067       1
# 999  -0.295480  -0.744903       1
#
# [1000 rows x 3 columns]

# %%
df['target'].unique()
# Out:
# array([0, 1])

# %%
df['target'].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
#upsampling -> upsample minority(Azınlığı Artırma)

# %%
#downsampling-> downsample majority(Çoğunluğu Azaltma)

# %%
#upsampling

# %%
df_minority = df[df["target"]== 1]

# %%
df_minority
# Out:
#      feature_1  feature_2  target
# 900   1.901191   0.696954       1
# 901  -0.060661  -0.333819       1
# 902  -0.708407   1.173125       1
# 903  -1.513714   0.369642       1
# 904  -1.803140  -0.107302       1
# ..         ...        ...     ...
# 995  -0.370011   1.070150       1
# 996  -0.258796  -0.026521       1
# 997   1.598647  -0.881875       1
# 998   0.560919  -0.163067       1
# 999  -0.295480  -0.744903       1
#
# [100 rows x 3 columns]

# %%
df_majority = df[df["target"]== 0]

# %%
df_majority
# Out:
#      feature_1  feature_2  target
# 0     0.496714   0.368673       0
# 1    -0.138264  -0.393339       0
# 2     0.647689   0.028745       0
# 3     1.523030   1.278452       0
# 4    -0.234153   0.191099       0
# ..         ...        ...     ...
# 895   0.648710  -0.751969       0
# 896  -0.167118  -0.319054       0
# 897   0.146714  -0.796026       0
# 898   1.206509   1.076007       0
# 899  -0.816936   0.021312       0
#
# [900 rows x 3 columns]

# %%
from sklearn.utils import resample

# %%
df_minority_upsampled = resample(df_minority,replace=True,n_samples=len(df_majority), random_state=42)

# %%
df_minority_upsampled.shape
# Out:
# (900, 3)

# %%
df_minority_upsampled.head()
# Out:
#      feature_1  feature_2  target
# 951   1.775311   1.261922       1
# 992  -0.436386   1.188913       1
# 914  -0.268531  -1.801058       1
# 971  -0.214921  -2.940389       1
# 960  -0.134309  -0.054894       1

# %%
df_upsampled = pd.concat([df_majority,df_minority_upsampled])

# %%
df_upsampled["target"].value_counts()
# Out:
# target
# 0    900
# 1    900
# Name: count, dtype: int64

# %%
df_majority_downsampled = resample(df_majority,replace=True,n_samples=len(df_minority), random_state=42)

# %%
df_majority_downsampled
# Out:
#      feature_1  feature_2  target
# 102  -0.342715   0.059630       0
# 435   0.074095  -0.337086       0
# 860   0.202923   1.639965       0
# 270   1.441273   0.758929       0
# 106   1.886186   0.895193       0
# ..         ...        ...     ...
# 201   0.560785  -2.896255       0
# 269   0.130741   0.853416       0
# 862   1.547505   0.075434       0
# 815  -1.485560  -0.090533       0
# 270   1.441273   0.758929       0
#
# [100 rows x 3 columns]

# %%
df_majority_downsampled["target"].value_counts()
# Out:
# target
# 0    100
# Name: count, dtype: int64

# %%
df_downsampled = pd.concat([df_majority_downsampled, df_minority])

# %%
df_downsampled["target"].value_counts()
# Out:
# target
# 0    100
# 1    100
# Name: count, dtype: int64

# %%
#SMOTE(Synthetic Minority Over-sampling Technique)

# %%
#Sadece kopyalama yapmak yerine, azınlık sınıfından yeni ve yapay örnekler üreten

# %%
df
# Out:
#      feature_1  feature_2  target
# 0     0.496714   0.368673       0
# 1    -0.138264  -0.393339       0
# 2     0.647689   0.028745       0
# 3     1.523030   1.278452       0
# 4    -0.234153   0.191099       0
# ..         ...        ...     ...
# 995  -0.370011   1.070150       1
# 996  -0.258796  -0.026521       1
# 997   1.598647  -0.881875       1
# 998   0.560919  -0.163067       1
# 999  -0.295480  -0.744903       1
#
# [1000 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(df["feature_1"], df["feature_2"], c=df["target"])

# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in C:\Users\serif.DESKTOP-P8O744N\anaconda3\Lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in C:\Users\serif.DESKTOP-P8O744N\anaconda3\Lib\site-packages (from imblearn) (0.14.1)
# Requirement already satisfied: numpy<3,>=1.25.2 in C:\Users\serif.DESKTOP-P8O744N\anaconda3\Lib\site-packages (from imbalanced-learn->imblearn) (2.3.5)
# Requirement already satisfied: scipy<2,>=1.11.4 in C:\Users\serif.DESKTOP-P8O744N\anaconda3\Lib\site-packages (from imbalanced-learn->imblearn) (1.16.3)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in C:\Users\serif.DESKTOP-P8O744N\anaconda3\Lib\site-packages (from imbalanced-learn->imblearn) (1.8.0)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in C:\Users\serif.DESKTOP-P8O744N\anaconda3\Lib\site-packages (from imbalanced-learn->imblearn) (0.1.5)
# Requirement already satisfied: joblib<2,>=1.2.0 in C:\Users\serif.DESKTOP-P8O744N\anaconda3\Lib\site-packages (from imbalanced-learn->imblearn) (1.5.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in C:\Users\serif.DESKTOP-P8O744N\anaconda3\Lib\site-packages (from imbalanced-learn->imblearn) (3.6.0)

# %%
from imblearn.over_sampling import SMOTE

# %%
oversample = SMOTE()

# %%
(X,y) = oversample.fit_resample(df[["feature_1", "feature_2"]], df["target"])

# %%
X
# Out:
#       feature_1  feature_2
# 0      0.496714   0.368673
# 1     -0.138264  -0.393339
# 2      0.647689   0.028745
# 3      1.523030   1.278452
# 4     -0.234153   0.191099
# ...         ...        ...
# 1795   0.701868  -0.173309
# 1796   1.545917  -1.335943
# 1797   1.358114  -0.225781
# 1798   0.486916  -0.147628
# 1799   0.504733  -1.114370
#
# [1800 rows x 2 columns]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1795    1
# 1796    1
# 1797    1
# 1798    1
# 1799    1
# Name: target, Length: 1800, dtype: int64

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
oversample_df = pd.concat([X,y], axis=1)

# %%
oversample_df["target"].value_counts()
# Out:
# target
# 0    900
# 1    900
# Name: count, dtype: int64

# %%
plt.scatter(df["feature_1"], df["feature_2"], c=df["target"])

# %%
plt.scatter(oversample_df["feature_1"], oversample_df["feature_2"], c=oversample_df["target"])
