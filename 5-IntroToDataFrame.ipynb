# %%
import pandas as pd

# %%
import numpy as np

# %%
data = np.random.randn(4,3)

# %%
data
# Out:
# array([[-1.33328023, -0.57033934, -0.58451834],
#        [-0.57958232,  0.04352402,  0.50200068],
#        [-0.75024015,  0.00848286,  0.612477  ],
#        [ 0.6719885 ,  1.36406035,  2.17863067]])

# %%
data_frame = pd.DataFrame(data)

# %%
data_frame #excel verisi gibi gösteriyor
# Out:
#           0         1         2
# 0 -1.333280 -0.570339 -0.584518
# 1 -0.579582  0.043524  0.502001
# 2 -0.750240  0.008483  0.612477
# 3  0.671988  1.364060  2.178631

# %%
type(data_frame)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data_frame[0])
# Out:
# pandas.core.series.Series

# %%
new_df =pd.DataFrame(data, index=["Serife","Zehra","Ufuk","Umut"],columns=["Salary","Age","Seniority"])

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Serife -1.333280 -0.570339  -0.584518
# Zehra  -0.579582  0.043524   0.502001
# Ufuk   -0.750240  0.008483   0.612477
# Umut    0.671988  1.364060   2.178631

# %%
new_df["Age"]
# Out:
# Serife   -0.570339
# Zehra     0.043524
# Ufuk      0.008483
# Umut      1.364060
# Name: Age, dtype: float64

# %%
new_df["Salary"]
# Out:
# Serife   -1.333280
# Zehra    -0.579582
# Ufuk     -0.750240
# Umut      0.671988
# Name: Salary, dtype: float64

# %%
new_df[["Age","Salary"]]
# Out:
#              Age    Salary
# Serife -0.570339 -1.333280
# Zehra   0.043524 -0.579582
# Ufuk    0.008483 -0.750240
# Umut    1.364060  0.671988

# %%
new_df.loc["Serife"]
# Out:
# Salary      -1.333280
# Age         -0.570339
# Seniority   -0.584518
# Name: Serife, dtype: float64

# %%
new_df.iloc[1]
# Out:
# Salary      -0.579582
# Age          0.043524
# Seniority    0.502001
# Name: Zehra, dtype: float64

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Serife -1.333280 -0.570339  -0.584518
# Zehra  -0.579582  0.043524   0.502001
# Ufuk   -0.750240  0.008483   0.612477
# Umut    0.671988  1.364060   2.178631

# %%
new_df.iloc[:,2] # :-->tüm rowları sec
# Out:
# Serife   -0.584518
# Zehra     0.502001
# Ufuk      0.612477
# Umut      2.178631
# Name: Seniority, dtype: float64

# %%
new_df["Extra"] = 10

# %%
new_df
# Out:
#           Salary       Age  Seniority  Extra
# Serife -1.333280 -0.570339  -0.584518     10
# Zehra  -0.579582  0.043524   0.502001     10
# Ufuk   -0.750240  0.008483   0.612477     10
# Umut    0.671988  1.364060   2.178631     10

# %%
new_df.drop("Extra",axis = 1)
# Out:
#           Salary       Age  Seniority
# Serife -1.333280 -0.570339  -0.584518
# Zehra  -0.579582  0.043524   0.502001
# Ufuk   -0.750240  0.008483   0.612477
# Umut    0.671988  1.364060   2.178631

# %%
new_df
# Out:
#           Salary       Age  Seniority  Extra
# Serife -1.333280 -0.570339  -0.584518     10
# Zehra  -0.579582  0.043524   0.502001     10
# Ufuk   -0.750240  0.008483   0.612477     10
# Umut    0.671988  1.364060   2.178631     10

# %%
new_df.drop("Extra",axis=1,inplace=True) #new_df = new_df.drop

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Serife -1.333280 -0.570339  -0.584518
# Zehra  -0.579582  0.043524   0.502001
# Ufuk   -0.750240  0.008483   0.612477
# Umut    0.671988  1.364060   2.178631

# %%
new_df["Umut"]= 10

# %%
new_df
# Out:
#           Salary       Age  Seniority  Umut
# Serife -1.333280 -0.570339  -0.584518    10
# Zehra  -0.579582  0.043524   0.502001    10
# Ufuk   -0.750240  0.008483   0.612477    10
# Umut    0.671988  1.364060   2.178631    10

# %%
new_df.drop("Umut")
# Out:
#           Salary       Age  Seniority  Umut
# Serife -1.333280 -0.570339  -0.584518    10
# Zehra  -0.579582  0.043524   0.502001    10
# Ufuk   -0.750240  0.008483   0.612477    10

# %%
new_df
# Out:
#           Salary       Age  Seniority  Umut
# Serife -1.333280 -0.570339  -0.584518    10
# Zehra  -0.579582  0.043524   0.502001    10
# Ufuk   -0.750240  0.008483   0.612477    10
# Umut    0.671988  1.364060   2.178631    10

# %%
new_df.drop("Umut", axis=1,inplace=True)

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Serife -1.333280 -0.570339  -0.584518
# Zehra  -0.579582  0.043524   0.502001
# Ufuk   -0.750240  0.008483   0.612477
# Umut    0.671988  1.364060   2.178631

# %%
new_df.drop("Umut", axis=0)
# Out:
#           Salary       Age  Seniority
# Serife -1.333280 -0.570339  -0.584518
# Zehra  -0.579582  0.043524   0.502001
# Ufuk   -0.750240  0.008483   0.612477

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Serife -1.333280 -0.570339  -0.584518
# Zehra  -0.579582  0.043524   0.502001
# Ufuk   -0.750240  0.008483   0.612477
# Umut    0.671988  1.364060   2.178631

# %%
new_df.loc["Serife"]
# Out:
# Salary      -1.333280
# Age         -0.570339
# Seniority   -0.584518
# Name: Serife, dtype: float64

# %%
new_df.loc["Serife"]["Salary"]
# Out:
# np.float64(-1.3332802330538838)

# %%
new_df.loc["Serife","Salary"]
# Out:
# np.float64(-1.3332802330538838)

# %%
new_df.loc["Serife","Salary"]=100

# %%
new_df
# Out:
#             Salary       Age  Seniority
# Serife  100.000000 -0.570339  -0.584518
# Zehra    -0.579582  0.043524   0.502001
# Ufuk     -0.750240  0.008483   0.612477
# Umut      0.671988  1.364060   2.178631

# %%
new_df > 0
# Out:
#         Salary    Age  Seniority
# Serife    True  False      False
# Zehra    False   True       True
# Ufuk     False   True       True
# Umut      True   True       True

# %%
boolean_frame = new_df >0

# %%
new_df[boolean_frame]
# Out:
#             Salary       Age  Seniority
# Serife  100.000000       NaN        NaN
# Zehra          NaN  0.043524   0.502001
# Ufuk           NaN  0.008483   0.612477
# Umut      0.671988  1.364060   2.178631

# %%
new_df[new_df>0]
# Out:
#             Salary       Age  Seniority
# Serife  100.000000       NaN        NaN
# Zehra          NaN  0.043524   0.502001
# Ufuk           NaN  0.008483   0.612477
# Umut      0.671988  1.364060   2.178631

# %%
new_df[new_df["Salary"]>1]
# Out:
#         Salary       Age  Seniority
# Serife   100.0 -0.570339  -0.584518

# %%
new_df
# Out:
#             Salary       Age  Seniority
# Serife  100.000000 -0.570339  -0.584518
# Zehra    -0.579582  0.043524   0.502001
# Ufuk     -0.750240  0.008483   0.612477
# Umut      0.671988  1.364060   2.178631

# %%
new_df.reset_index()
# Out:
#     index      Salary       Age  Seniority
# 0  Serife  100.000000 -0.570339  -0.584518
# 1   Zehra   -0.579582  0.043524   0.502001
# 2    Ufuk   -0.750240  0.008483   0.612477
# 3    Umut    0.671988  1.364060   2.178631

# %%
reset_frame = new_df.reset_index()

# %%
reset_frame
# Out:
#     index      Salary       Age  Seniority
# 0  Serife  100.000000 -0.570339  -0.584518
# 1   Zehra   -0.579582  0.043524   0.502001
# 2    Ufuk   -0.750240  0.008483   0.612477
# 3    Umut    0.671988  1.364060   2.178631

# %%
reset_frame.loc[0]
# Out:
# index          Serife
# Salary          100.0
# Age         -0.570339
# Seniority   -0.584518
# Name: 0, dtype: object

# %%
new_indices = ["Sero","Zehr","Ufu","Umud"]

# %%
new_df["NewIndex"] = new_indices

# %%
new_df
# Out:
#             Salary       Age  Seniority NewIndex
# Serife  100.000000 -0.570339  -0.584518     Sero
# Zehra    -0.579582  0.043524   0.502001     Zehr
# Ufuk     -0.750240  0.008483   0.612477      Ufu
# Umut      0.671988  1.364060   2.178631     Umud

# %%
new_df.set_index("NewIndex", inplace=True)

# %%
new_df
# Out:
#               Salary       Age  Seniority
# NewIndex
# Sero      100.000000 -0.570339  -0.584518
# Zehr       -0.579582  0.043524   0.502001
# Ufu        -0.750240  0.008483   0.612477
# Umud        0.671988  1.364060   2.178631

# %%
new_df.loc["Sero"]
# Out:
# Salary       100.000000
# Age           -0.570339
# Seniority     -0.584518
# Name: Sero, dtype: float64

# %%
# multi index

# %%
first_index = ["Simpson","Simpson","Simpson","South Park","South Park","South Park"]

# %%
inner_index = ["Homer","Bart","Marge","Cartman","Kenny","Kyle"]

# %%
zipped_index = list(zip(first_index,inner_index))

# %%
zipped_index
# Out:
# [('Simpson', 'Homer'),
#  ('Simpson', 'Bart'),
#  ('Simpson', 'Marge'),
#  ('South Park', 'Cartman'),
#  ('South Park', 'Kenny'),
#  ('South Park', 'Kyle')]

# %%
zipped_index = pd.MultiIndex.from_tuples(zipped_index)

# %%
zipped_index
# Out:
# MultiIndex([(   'Simpson',   'Homer'),
#             (   'Simpson',    'Bart'),
#             (   'Simpson',   'Marge'),
#             ('South Park', 'Cartman'),
#             ('South Park',   'Kenny'),
#             ('South Park',    'Kyle')],
#            )

# %%
sample_values = np.ones((6,2))

# %%
big_df = pd.DataFrame(sample_values,index = zipped_index, columns = ["Age","Salary"])

# %%
big_df
# Out:
#                     Age  Salary
# Simpson    Homer    1.0     1.0
#            Bart     1.0     1.0
#            Marge    1.0     1.0
# South Park Cartman  1.0     1.0
#            Kenny    1.0     1.0
#            Kyle     1.0     1.0

# %%
big_df["Age"]
# Out:
# Simpson     Homer      1.0
#             Bart       1.0
#             Marge      1.0
# South Park  Cartman    1.0
#             Kenny      1.0
#             Kyle       1.0
# Name: Age, dtype: float64

# %%
big_df.loc["Simpson"]
# Out:
#        Age  Salary
# Homer  1.0     1.0
# Bart   1.0     1.0
# Marge  1.0     1.0

# %%
big_df.loc["Simpson"].lo
