# %%
import numpy as np

# %%
new_array = np.random.randint(1,100,20)

# %%
new_array
# Out:
# array([65, 70, 21, 33, 70, 91, 18, 66, 56, 25, 57, 74, 61, 88, 44, 96,  7,
#        62, 56, 97], dtype=int32)

# %%
new_array>25
# Out:
# array([ True,  True, False,  True,  True,  True, False,  True,  True,
#        False,  True,  True,  True,  True,  True,  True, False,  True,
#         True,  True])

# %%
new_array[new_array>25]
# Out:
# array([65, 70, 33, 70, 91, 66, 56, 57, 74, 61, 88, 44, 96, 62, 56, 97],
#       dtype=int32)

# %%
new_array[new_array<25]
# Out:
# array([21, 18,  7], dtype=int32)

# %%
# transpose & reshape

# %%
matrix_array = np.array([[10,20],[20,30],[30,40]])

# %%
matrix_array
# Out:
# array([[10, 20],
#        [20, 30],
#        [30, 40]])

# %%
matrix_array.shape
# Out:
# (3, 2)

# %%
matrix_array.transpose()
# Out:
# array([[10, 20, 30],
#        [20, 30, 40]])

# %%
matrix_array.T
# Out:
# array([[10, 20, 30],
#        [20, 30, 40]])

# %%
random_array = np.random.random((6,1))

# %%
random_array
# Out:
# array([[0.01687904],
#        [0.97530268],
#        [0.29058165],
#        [0.43973586],
#        [0.89038043],
#        [0.14278629]])

# %%
random_array.shape
# Out:
# (6, 1)

# %%
random_array.reshape(2,3)
# Out:
# array([[0.01687904, 0.97530268, 0.29058165],
#        [0.43973586, 0.89038043, 0.14278629]])

# %%
random_array.reshape(3,2)
# Out:
# array([[0.01687904, 0.97530268],
#        [0.29058165, 0.43973586],
#        [0.89038043, 0.14278629]])

# %%
# z-score

# %%
data = np.array([10,12,13,15,18,25,100,105])

# %%
#outlier

# %%
mean = np.mean(data)

# %%
mean
# Out:
# np.float64(37.25)

# %%
data.sum() / len(data)
# Out:
# np.float64(37.25)

# %%
std = np.std(data)

# %%
std
# Out:
# np.float64(37.9333296719389)

# %%
z_scores = (data - mean) / std

# %%
z_scores
# Out:
# array([-0.71836562, -0.66564154, -0.6392795 , -0.58655542, -0.50746929,
#        -0.322935  ,  1.65421809,  1.78602829])

# %%
data[z_scores>1]
# Out:
# array([100, 105])

# %%
#math equations

# %%
# 2x + 3y = 8 and 5x + 7y = 19

# %%
#coefficient

# %%
A = np.array([[2,3],[5,7]])

# %%
#constant

# %%
b = np.array([8,19])

# %%
solution = np.linalg.solve(A,b)

# %%
soluti
